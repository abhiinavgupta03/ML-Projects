# %% [markdown]
# <a href="https://colab.research.google.com/github/abhiinavgupta03/ML-Projects/blob/main/Diabetes_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# all major functions in preprocessing a data

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('/content/diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
from matplotlib import pyplot

#density plot
df.plot(kind='density',subplots=True,layout=(4,4),sharex=False,sharey=False)
pyplot.show()

# %%
#box plot

df.plot(kind='box',subplots=True,layout=(4,4),sharex=False,sharey=False)
pyplot.show()

# %%
#scatter plot

from pandas.plotting import scatter_matrix
scatter_matrix(df, alpha=1.0, figsize=(10, 10))
pyplot.show()

# %%
  x=df.drop(columns='Outcome',axis=1)
y=df['Outcome']
print(x)
print(y)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
scaler=StandardScaler()
X=scaler.fit_transform(x)
print(X)
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)
print(X_train.shape,X_test.shape)
# Out:
# (614, 8) (154, 8)

# %%
print(X_train)
# Out:
# [[-0.84488505  0.09719231  0.25303625 ... -0.53211885 -1.12311057
#   -0.27575966]
#  [-0.84488505 -0.81042491  0.66661825 ...  0.38169971 -0.72143478
#    0.83038113]
#  [-1.14185152 -0.84172205  0.04624525 ...  1.4605133  -0.37714125
#   -1.04154944]
#  ...
#  [ 0.04601433  0.12848945  0.04624525 ... -0.39250768  2.02989333
#    1.00055664]
#  [-0.25095213 -0.15318486  0.25303625 ... -0.72249772 -1.10196973
#   -0.78628618]
#  [ 0.04601433 -0.34096773 -0.16054575 ... -0.01174995 -0.00264654
#   -0.36084741]]
